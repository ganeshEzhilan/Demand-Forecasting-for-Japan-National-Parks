# %% [markdown]
# #Exploring data

# %%
import os
import pandas as pd
data_path = "/Users/abhishekkumar/Documents/MS_UB/Fall_18/ESL506_StatisticalDataMiningI/Project/SIGNATE/translated/"
train = pd.read_table(os.path.join(data_path,"'ttrain.tsv'.txt"))
test = pd.read_table(os.path.join(data_path,"'ttest.tsv'.txt"))
hotlink = pd.read_table(os.path.join(data_path,"'thotlink.tsv'.txt"))
nightley = pd.read_table(os.path.join(data_path,"'nightley.tsv'.txt"))

colopl = pd.read_table(os.path.join(data_path,"'tcolopl.tsv'.txt"))
jorudan = pd.read_table(os.path.join(data_path,"tjorudan.tsv"))

# %%
weather = pd.read_table(os.path.join(data_path,"'tweather.tsv'.txt"))

# %%
set(weather["elocation"])
# Out:
# {'Aomori',
#  'Daejeon',
#  'Kagoshima',
#  'Kazuno',
#  'Kumamoto',
#  'Kushiro',
#  'Nikko',
#  'Oyama',
#  'Takamori',
#  'Toba',
#  'Tokashiki',
#  'Towada'}

# %%
weather.head()
# Out:
#         date  Average temperature (℃)  Highest temperature (℃)  \
# 0   2015/1/1                     -1.9                      0.3
# 1   2015/1/3                     -4.0                     -1.6
# 2   2015/1/5                      0.8                      5.4
# 3   2015/1/7                     -3.7                     -1.2
# 4  2015/1/10                     -0.5                      1.8
#
#    Lowest temperature (° C)  Total precipitation (mm)  \
# 0                      -2.9                       5.0
# 1                      -8.9                       2.0
# 2                      -5.1                       0.0
# 3                      -5.5                       0.0
# 4                      -2.1                       0.0
#
#    10 minutes Maximum precipitation (mm)  Daylight hours (hours)  \
# 0                                    1.0                     2.1
# 1                                    0.5                     1.4
# ...

# %%
train.head()
# Out:
#      datetime                      epark  visitors
# 0  2015-01-01  Akan Megumi National Park     11028
# 1  2015-01-02  Akan Megumi National Park     11153
# 2  2015-01-03  Akan Megumi National Park     12343
# 3  2015-01-04  Akan Megumi National Park      6732
# 4  2015-01-05  Akan Megumi National Park      4877

# %%
test.head()
# Out:
#    index    datetime                             epark
# 0      0  2017-01-01         Akan Megumi National Park
# 1      1  2017-01-01  Towada Hachimantai National Park
# 2      2  2017-01-01               Nikko National Park
# 3      3  2017-01-01           Ise Shima National Park
# 4      4  2017-01-01           Oyama Oki National Park

# %%
colopl.head()
# Out:
#    year  month                             epark               ecountry_jp  \
# 0  2016      1         Akan Megumi National Park  United States of America
# 1  2016      1  Towada Hachimantai National Park  United States of America
# 2  2016      1               Nikko National Park  United States of America
# 3  2016      1           Ise Shima National Park  United States of America
# 4  2016      1         Akan Megumi National Park                 Singapore
#
#   count
# 0   1-9
# 1   1-9
# 2   1-9
# 3   1-9
# 4   1-9

# %%
hotlink.head()
# Out:
#      datetime            domain       ekeyword  count
# 0  2015-01-01  twitter_sampling  National park    148
# 1  2015-01-01              blog    Hakkodayama     49
# 2  2015-01-01               bbs    Hakkodayama      4
# 3  2015-01-01               bbs    Shuanghutai      0
# 4  2015-01-01              blog    Shuanghutai      0

# %%
nightley.head()  #Social Meadia postings
# Out:
#      datetime  Japan_count  Foreign_count
# 0  2016-01-01           28              0
# 1  2016-01-02           66              1
# 2  2016-01-03           75              6
# 3  2016-01-04           50              1
# 4  2016-01-05           25              0

# %%
jorudan.head()   #route search data
# Out:
#   access_date access_time departure_and_arrival_type  \
# 0  2015-01-26    01:26:15                          D
# 1  2015-01-01    22:07:13                          D
# 2  2015-01-04    22:32:10                          D
# 3  2015-01-04    22:41:43                          D
# 4  2015-01-05    16:48:34                          A
#
#   departure_and_arrival_date departure_and_arrival_time  \
# 0                 2015-01-28                      12:02
# 1                 2015-01-02                      04:00
# 2                 2015-01-31                      19:30
# 3                 2015-01-31                      19:30
# 4                 2015-01-20                      03:59
#
#   departure_and_arrival_place_type                epark edeparture_prefecture  \
# 0                                D  Nikko National Park               Tochigi
# 1                                D  Nikko National Park               Tochigi
# ...

# %%
set(train['epark'])
# Out:
# {'Akan Megumi National Park',
#  'Aso Kuju National Park',
#  'Ise Shima National Park',
#  'Kerama islands national park',
#  'Kirishima Jinjiang Bay National Park',
#  'Nikko National Park',
#  'Oyama Oki National Park',
#  'Towada Hachimantai National Park'}

# %%
import matplotlib.pyplot as plt
train_df = train.copy()
train_df.index = pd.to_datetime(train_df["datetime"])
train_df = train_df.drop("datetime", axis=1)

# %%
akan = train_df[train_df["epark"] == "Akan Megumi National Park"]
akan = akan.drop("epark", axis=1)
aso = train_df[train_df["epark"] == "Aso Kuju National Park"]
aso = aso.drop("epark", axis=1)
ise = train_df[train_df["epark"] == "Ise Shima National Park"]
ise = ise.drop("epark", axis=1)
kerama = train_df[train_df["epark"] == "Kerama islands national park"]
kerama = kerama.drop("epark", axis=1)
kirishima = train_df[train_df["epark"] == "Kirishima Jinjiang Bay National Park"]
kirishima = kirishima.drop("epark", axis=1)
nikko = train_df[train_df["epark"] == "Nikko National Park"]
nikko = nikko.drop("epark", axis=1)
oyama = train_df[train_df["epark"] == "Oyama Oki National Park"]
oyama = oyama.drop("epark", axis=1)
towada = train_df[train_df["epark"] == "Towada Hachimantai National Park"]
towada = towada.drop("epark", axis=1)

# %%
#%matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=[16,8])
#plt.plot(akun.resample('W').sum())
plt.plot(aso.resample('W').sum())
#plt.plot(ise.resample('W').sum())
plt.plot(kerama.resample('W').sum())
#plt.plot(kirishima.resample('W').sum())
#plt.plot(nikko.resample('W').sum())
plt.plot(oyama.resample('W').sum())
#plt.plot(towada.resample('W').sum())
#fig.legend(["akun", "aso", "ise", "kerama","kirishima","nikko","oyama","towada"]);
fig.legend(["aso", "kerama","oyama"]);

# %%
fig = plt.figure(figsize=[16,8])
plt.plot(akan.resample('W').sum())
#plt.plot(aso.resample('W').sum())
plt.plot(ise.resample('W').sum())
#plt.plot(kerama.resample('W').sum())
plt.plot(kirishima.resample('W').sum())
plt.plot(nikko.resample('W').sum())
#plt.plot(oyama.resample('W').sum())
plt.plot(towada.resample('W').sum())
fig.legend(["akan", "ise","kirishima","nikko","towada"]);
#fig.legend(["aso", "kerama","oyama"]);

# %%
fig = plt.figure(figsize=[16,8])
plt.plot(akan.resample('M').mean())
#plt.plot(aso.resample('W').sum())
plt.plot(ise.resample('M').mean())
#plt.plot(kerama.resample('W').sum())
plt.plot(kirishima.resample('M').mean())
plt.plot(nikko.resample('M').mean())
#plt.plot(oyama.resample('W').sum())
plt.plot(towada.resample('M').mean())
fig.legend(["akan", "ise","kirishima","nikko","towada"]);
#fig.legend(["aso", "kerama","oyama"]);

# %%
fig = plt.figure(figsize=[16,8])
#plt.plot(akun.resample('W').sum())
plt.plot(aso.resample('M').sum())
#plt.plot(ise.resample('W').sum())
plt.plot(kerama.resample('M').sum())
#plt.plot(kirishima.resample('W').sum())
#plt.plot(nikko.resample('W').sum())
plt.plot(oyama.resample('M').sum())
#plt.plot(towada.resample('W').sum())
#fig.legend(["akun", "aso", "ise", "kerama","kirishima","nikko","oyama","towada"]);
fig.legend(["aso", "kerama","oyama"]);

# %%
fig = plt.figure(figsize=[16,8])
by_weekday = akan.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = ise.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = kirishima.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = nikko.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = towada.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
fig.legend(["akun", "ise","kirishima","nikko","towada"]);

# %%
fig = plt.figure(figsize=[16,8])
by_weekday = aso.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = kerama.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
by_weekday = oyama.copy()
by_weekday = by_weekday.groupby(by_weekday.index.dayofweek)
plt.plot(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'],by_weekday.mean())
fig.legend(["aso", "kerama","oyama"]);
plt.title("Weekly Sampled Data")
# Out:
# Text(0.5, 1.0, 'Weekly Sampled Data')

# %%
plt.figure(figsize=[20,10])
by_weekday.boxplot()
# Out:
# 0         AxesSubplot(0.1,0.679412;0.235294x0.220588)
# 1    AxesSubplot(0.382353,0.679412;0.235294x0.220588)
# 2    AxesSubplot(0.664706,0.679412;0.235294x0.220588)
# 3         AxesSubplot(0.1,0.414706;0.235294x0.220588)
# 4    AxesSubplot(0.382353,0.414706;0.235294x0.220588)
# 5    AxesSubplot(0.664706,0.414706;0.235294x0.220588)
# 6             AxesSubplot(0.1,0.15;0.235294x0.220588)
# dtype: object
